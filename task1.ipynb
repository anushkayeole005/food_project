# %% [markdown]
# <a href="https://colab.research.google.com/github/anushkayeole005/food_project/blob/main/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
correct_username = "admin"
correct_password = "1234"

username = input("Enter Username: ")
password = input("Enter Password: ")

if username == correct_username and password == correct_password:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter Username: admin
# Enter Password: 1234
# Login Successful

# %%
marks = [45, 78, 90, 33, 60]

pass_count = 0
fail_count = 0

for mark in marks:
    if mark >= 50:
        pass_count += 1
    else:
        fail_count += 1

print("Total Students:", len(marks))
print("Number of Students Passed:", pass_count)
print("Number of Students Failed:", fail_count)
# Out:
# Total Students: 5
# Number of Students Passed: 3
# Number of Students Failed: 2

# %%
names = [" Anushka ", "Yashwini", " Nidhisha "]


cleaned_names = []

for name in names:
    cleaned_name = name.strip().lower()
    cleaned_names.append(cleaned_name)


print("Original Names:", names)
print("Cleaned Names:", cleaned_names)
# Out:
# Original Names: [' Anushka ', 'Yashwini', ' Nidhisha ']
# Cleaned Names: ['anushka', 'yashwini', 'nidhisha']

# %%
messages = ["Hi", "I am Anushka", "OK"]

print("----- Message Length Analysis -----")

for message in messages:
    length = len(message)
    print(f"Message: '{message}'")
    print("Length:", length)

    if length > 10:
        print("Status: Long message ")
    else:
        print("Status: Short message")

    print()
# Out:
# ----- Message Length Analysis -----
# Message: 'Hi'
# Length: 2
# Status: Short message
#
# Message: 'I am Anushka'
# Length: 12
# Status: Long message
#
# Message: 'OK'
# Length: 2
# Status: Short message

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

error_count = 0

for log in logs:
    if log == "ERROR":
        error_count += 1

print("System Logs:", logs)
print("Total ERROR entries:", error_count)
# Out:
# System Logs: ['INFO', 'ERROR', 'WARNING', 'ERROR']
# Total ERROR entries: 2
